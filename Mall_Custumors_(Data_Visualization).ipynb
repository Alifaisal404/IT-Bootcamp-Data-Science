# %% [markdown]
# IBA IT INDUSTRY READINESS BOOTCAMP PROGRAM at *FAST University*

# %% [markdown]
# Faisal Ali
#
# Program  : Data Science With Python
#
# Class Room Task | Mall Custumors (Data Visualization)
#
# ---

# %% [markdown]
# This is not a public notebooik, It is uploaded to our GoogleClass room
# Dataset Link:
# >https://classroom.google.com/u/0/c/NjE1NzQxMDc5OTE1
#
#  OR
#  >https://docs.google.com/spreadsheets/d/1SajcVApKIQkiKZi1-Kd_dlHxXIwqK9ms9_5ulP0Goc0/edit#gid=363854230
#
#  Here I am sharing this data set as public from my drive
#  >https://drive.google.com/file/d/1gTmh_DPrqNWwunj6Mt-jbAHhdeMUyFFE/view?usp=sharing
#
#
#
# ---

# %% [markdown]
# Imporrting Libraries

# %%
from ast import increment_lineno
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# I have uploaded the data set to my drive, So I am loading it from there
from google.colab import drive
drive.mount('/content/drive')

custumer_df = pd.read_csv('/content/drive/MyDrive/datasets/mall_customers.csv')
custumer_df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %%
custumer_df.isna().sum()
# Out:
# CustomerID            0
# Genre                 0
# Age                   0
# Annual_Income_(k$)    0
# Spending_Score        0
# dtype: int64

# %%
custumer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          200 non-null    int64
#  1   Genre               200 non-null    object
#  2   Age                 200 non-null    int64
#  3   Annual_Income_(k$)  200 non-null    int64
#  4   Spending_Score      200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
custumer_df.describe()
# Out:
#        CustomerID         Age  Annual_Income_(k$)  Spending_Score
# count  200.000000  200.000000          200.000000      200.000000
# mean   100.500000   38.850000           60.560000       50.200000
# std     57.879185   13.969007           26.264721       25.823522
# min      1.000000   18.000000           15.000000        1.000000
# 25%     50.750000   28.750000           41.500000       34.750000
# 50%    100.500000   36.000000           61.500000       50.000000
# 75%    150.250000   49.000000           78.000000       73.000000
# max    200.000000   70.000000          137.000000       99.000000

# %%
data = custumer_df

# %%
custom_palette = sns.color_palette("Set2")
plt.figure(figsize=(12, 8))
sns.barplot(data=data, x='Age', y='Annual_Income_(k$)', palette=custom_palette)
plt.xlabel('Age')
plt.ylabel('Annual income k$')
plt.title('Barplot of Ages vs Annual Incomes k$')
plt.show()

# %%
custom_palette = sns.color_palette("Paired")
plt.figure(figsize=(20, 5))
ax = sns.barplot(data=data, x='Spending_Score', y='Annual_Income_(k$)', palette=custom_palette)
sns.set_style("whitegrid")
plt.xlabel('Spending Score')
plt.ylabel('Annual Income (k$)')
plt.title('Barplot of Spending Score vs. Annual Incomes')
plt.show()

# %%
custom_palette = sns.color_palette("coolwarm")
plt.figure(figsize=(20, 8))
ax = sns.barplot(data=data, x='Age', y='Spending_Score', palette=custom_palette)
sns.set_style("whitegrid")
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.title('Barplot of Ages vs. Spending Score')
plt.show()

# %%
custom_palette = sns.color_palette("Set1")
colors = [custom_palette[i % len(custom_palette)] for i in range(len(data))]

plt.figure(figsize=(12, 8))
sns.scatterplot(data=data, x='Age', y='Annual_Income_(k$)', color=colors)
plt.xlabel('Age')
plt.ylabel('Annual income k$')
plt.title('Scatterplot of Ages vs. Annual Incomes k$')
plt.show()

# %%
custom_palette = sns.color_palette("Set3")
plt.figure(figsize=(25, 8))
sns.boxplot(data=data, x='Age', y='Annual_Income_(k$)', palette=custom_palette)
plt.xlabel('Age')
plt.ylabel('Annual income k$')
plt.title('Boxplot of Ages vs. Annual Incomes k$')
plt.show()

# %% [markdown]
# Please note that the following cell will take a lot of time to load, so be patient!!!!!!!!!!!!!!!!

# %%
custom_palette = sns.color_palette("Set1")
custom_size = 50
plt.figure(figsize=(12, 8))
pairplot = sns.pairplot(data, hue='Age', palette=custom_palette,
                       plot_kws={'s': custom_size})

pairplot._legend.set_title('Age')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: UserWarning:
# The palette list has fewer values (9) than needed (51) and will cycle, which may produce an uninterpretable plot.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: UserWarning:
# The palette list has fewer values (9) than needed (51) and will cycle, which may produce an uninterpretable plot.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: UserWarning:
# The palette list has fewer values (9) than needed (51) and will cycle, which may produce an uninterpretable plot.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning:
# The palette list has fewer values (9) than needed (51) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning:
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

custom_palette = sns.color_palette("YlGnBu")

fig, ax = plt.subplots(figsize=(20, 8))
fig.patch.set_facecolor('none')

ax.add_patch(plt.Rectangle((0, 0), 1, 1, color='gray', alpha=0.1, transform=fig.transFigure))
sns.violinplot(data=df, x='Age', y='Annual_Income_(k$)', palette=custom_palette, inner='quart', ax=ax)
sns.stripplot(data=df, x='Age', y='Annual_Income_(k$)', color='blue', size=8, jitter=True, alpha=0.6, ax=ax)
ax.set_xlabel('Age', fontsize=14)
ax.set_ylabel('Annual income k$', fontsize=14)
ax.set_title('Violin Plot of Age vs. Annual Incomes k$', fontsize=16)
ax.tick_params(labelsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
custom_palette = sns.color_palette("Set1")
plt.figure(figsize=(30, 10))
plt.gca().set_facecolor('#000000')
ax = sns.countplot(data=df, x='Age', palette=custom_palette)

ax.set_xlabel('Age', fontsize=10)
ax.set_ylabel('Count', fontsize=10)
ax.set_title('Countplot of Age', fontsize=12)
ax.tick_params(labelsize=12)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.gca().set_facecolor('#000000')  # Set the background color
ax = sns.countplot(data=df, x='Annual_Income_(k$)', palette=custom_palette)
ax.set_xlabel('Annual Income (k$)', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
ax.set_title('Countplot of Annual Income', fontsize=16)
ax.tick_params(labelsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()
